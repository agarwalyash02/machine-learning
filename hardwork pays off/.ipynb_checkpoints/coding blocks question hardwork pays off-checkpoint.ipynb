# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X=pd.read_csv('./Training Data/Linear_X_Train.csv')
y=pd.read_csv('./Training Data/Linear_Y_Train.csv')

X=X.values
y=y.values

print(X.shape[0],y.shape[0])
u=X.mean()
std=X.std()
X=(X-u)/std

plt.style.use('seaborn')
plt.scatter(X,y,color='aqua')
plt.title("Hardwork vs Performance Graph")
plt.xlabel("Hardwork")
plt.ylabel("Performance")
plt.show()
# Out:
# 3750 3750

# %%
def hypothesis(x,thetha):
    y_=thetha[0]+thetha[1]*x
    return y_

def gradient(X,Y,thetha):
    m=X.shape[0]
    grad=np.zeros((2,))
    for i in range(m):
        x=X[i]
        y=Y[i]
        y_=hypothesis(x,thetha)
        grad[0]+=(y_ - y)
        grad[1]+=(y_ - y)*x
    return grad/m

def gradientdescent(X,Y,max_steps=100,learning_rate=0.1):
    thetha=np.zeros((2,))
    
    for i in range(max_steps):
        grad=gradient(X,Y,thetha)
        
        thetha[0]=thetha[0] - learning_rate*grad[0]
        thetha[1]=thetha[1] - learning_rate*grad[1]
       
        
    return thetha

# %%
thetha=gradientdescent(X,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-57f61d616eb2> in <module>
# ----> 1 thetha=gradientdescent(X,y)
#
# <ipython-input-22-9c1f342e9c0a> in gradientdescent(X, Y, max_steps, learning_rate)
#      18
#      19     for i in range(max_steps):
# ---> 20         grad=gradient(X,Y,thetha)
#      21
#      22         thetha[0]=thetha[0] - learning_rate*grad[0]
#
# <ipython-input-27-b17200fbeb50> in gradient(X, Y, thetha)
#       5 def gradient(X,Y,thetha):
#       6     m=X.shape[0]
# ----> 7     grad=np.zeroes((2,))
#       8     for i in range(m):
#       9         x=X[i]
#
# AttributeError: module 'numpy' has no attribute 'zeroes'
